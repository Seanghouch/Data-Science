# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("file//homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(us$)')
plt.scatter(df.area, df.price)
plt.scatter(df.area, df.price, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.coef_ * 3300 + reg.intercept_
# Out:
# array([628715.75342466])

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
data = [2600, 3000, 3200, 3600, 4000]
target = [550000, 565000, 610000, 680000, 725000]
data = pd.DataFrame(data)
target = pd.DataFrame(target)
model = linear_model.LinearRegression()
model.fit(data, target)
model.coef_
# Out:
# array([[135.78767123]])

# %%
model.intercept_
# Out:
# array([180616.43835616])

# %%
model.predict([[5000]])
# Out:
# array([[859554.79452055]])

# %%
import pickle

# %%
with open('model_pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('model_pickle', 'rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[5000]])
# Out:
# array([[859554.79452055]])
